# %%
import pandas as pd
import os

# %%
df = pd.read_csv("global_terrorism_dataset.csv", encoding="latin1")
# Out:
# C:\Users\timor\AppData\Local\Temp\ipykernel_157356\1480915019.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("global_terrorism_dataset.csv", encoding="latin1")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
for i, col in enumerate(df.columns):
    print(f"{i}: {col}")
# Out:
# 0: eventid
# 1: iyear
# 2: imonth
# 3: iday
# 4: approxdate
# 5: extended
# 6: resolution
# 7: country
# 8: country_txt
# 9: region
# 10: region_txt
# 11: provstate
# 12: city
# 13: latitude
# 14: longitude
# 15: specificity
# 16: vicinity
# 17: location
# 18: summary
# 19: crit1
# 20: crit2
# 21: crit3
# 22: doubtterr
# 23: alternative
# 24: alternative_txt
# 25: multiple
# 26: success
# 27: suicide
# 28: attacktype1
# 29: attacktype1_txt
# 30: attacktype2
# 31: attacktype2_txt
# 32: attacktype3
# 33: attacktype3_txt
# 34: targtype1
# 35: targtype1_txt
# 36: targsubtype1
# 37: targsubtype1_txt
# 38: corp1
# 39: target1
# 40: natlty1
# 41: natlty1_txt
# 42: targtype2
# 43: targtype2_txt
# 44: targsubtype2
# 45: targsubtype2_txt
# 46: corp2
# 47: target2
# 48: natlty2
# 49: natlty2_txt
# 50: targtype3
# 51: targtype3_txt
# 52: targsubtype3
# 53: targsubtype3_txt
# 54: corp3
# 55: target3
# 56: natlty3
# 57: natlty3_txt
# 58: gname
# 59: gsubname
# 60: gname2
# 61: gsubname2
# 62: gname3
# 63: gsubname3
# 64: motive
# 65: guncertain1
# 66: guncertain2
# 67: guncertain3
# 68: individual
# 69: nperps
# 70: nperpcap
# 71: claimed
# 72: claimmode
# 73: claimmode_txt
# 74: claim2
# 75: claimmode2
# 76: claimmode2_txt
# 77: claim3
# 78: claimmode3
# 79: claimmode3_txt
# 80: compclaim
# 81: weaptype1
# 82: weaptype1_txt
# 83: weapsubtype1
# 84: weapsubtype1_txt
# 85: weaptype2
# 86: weaptype2_txt
# 87: weapsubtype2
# 88: weapsubtype2_txt
# 89: weaptype3
# 90: weaptype3_txt
# 91: weapsubtype3
# 92: weapsubtype3_txt
# 93: weaptype4
# 94: weaptype4_txt
# 95: weapsubtype4
# 96: weapsubtype4_txt
# 97: weapdetail
# 98: nkill
# 99: nkillus
# 100: nkillter
# 101: nwound
# 102: nwoundus
# 103: nwoundte
# 104: property
# 105: propextent
# 106: propextent_txt
# 107: propvalue
# 108: propcomment
# 109: ishostkid
# 110: nhostkid
# 111: nhostkidus
# 112: nhours
# 113: ndays
# 114: divert
# 115: kidhijcountry
# 116: ransom
# 117: ransomamt
# 118: ransomamtus
# 119: ransompaid
# 120: ransompaidus
# 121: ransomnote
# 122: hostkidoutcome
# 123: hostkidoutcome_txt
# 124: nreleased
# 125: addnotes
# 126: scite1
# 127: scite2
# 128: scite3
# 129: dbsource
# 130: INT_LOG
# 131: INT_IDEO
# 132: INT_MISC
# 133: INT_ANY
# 134: related

# %%
columns_to_keep = [
        'iyear',
        'country_txt',
        'attacktype1_txt',
        'nkill',
        'nwound',
        'gname',
        'targtype1_txt',
        'weaptype1_txt'
    ]

df = df[columns_to_keep].copy()

    # Fehlende Werte bereinigen
df['nkill'] = df['nkill'].fillna(0)
df['nwound'] = df['nwound'].fillna(0)

    # Gesamte Opferzahl berechnen
df['casualties'] = df['nkill'] + df['nwound']

df
# Out:
#         iyear         country_txt                 attacktype1_txt  nkill  \
# 0        1970  Dominican Republic                   Assassination    1.0
# 1        1970              Mexico     Hostage Taking (Kidnapping)    0.0
# 2        1970         Philippines                   Assassination    1.0
# 3        1970              Greece               Bombing/Explosion    0.0
# 4        1970               Japan  Facility/Infrastructure Attack    0.0
# ...       ...                 ...                             ...    ...
# 181686   2017             Somalia                   Armed Assault    1.0
# 181687   2017               Syria               Bombing/Explosion    2.0
# 181688   2017         Philippines  Facility/Infrastructure Attack    0.0
# 181689   2017               India               Bombing/Explosion    0.0
# 181690   2017         Philippines               Bombing/Explosion    0.0
#
#         nwound                                       gname  \
# 0          0.0                                      MANO-D
# 1          0.0          23rd of September Communist League
# 2          0.0                                     Unknown
# 3          0.0                                     Unknown
# 4          0.0                                     Unknown
# ...        ...                                         ...
# 181686     2.0                                  Al-Shabaab
# 181687     7.0                           Muslim extremists
# 181688     0.0  Bangsamoro Islamic Freedom Movement (BIFM)
# 181689     0.0                                     Unknown
# 181690     0.0                                     Unknown
#
#                       targtype1_txt weaptype1_txt  casualties
# 0       Private Citizens & Property       Unknown         1.0
# 1           Government (Diplomatic)       Unknown         0.0
# 2               Journalists & Media       Unknown         1.0
# 3           Government (Diplomatic)    Explosives         0.0
# 4           Government (Diplomatic)    Incendiary         0.0
# ...                             ...           ...         ...
# 181686                     Military      Firearms         3.0
# 181687                     Military    Explosives         9.0
# 181688  Private Citizens & Property    Incendiary         0.0
# 181689         Government (General)    Explosives         0.0
# 181690                      Unknown    Explosives         0.0
#
# [181691 rows x 9 columns]

# %%
df[df["country_txt"] == "Lebanon"]
# Out:
#         iyear country_txt              attacktype1_txt  nkill  nwound  \
# 158      1970     Lebanon            Bombing/Explosion    0.0     0.0
# 1005     1971     Lebanon                    Hijacking    0.0     0.0
# 1448     1972     Lebanon                    Hijacking    0.0     0.0
# 1606     1972     Lebanon                    Hijacking    0.0     0.0
# 1669     1972     Lebanon            Bombing/Explosion    0.0     0.0
# ...       ...         ...                          ...    ...     ...
# 178169   2017     Lebanon            Bombing/Explosion    1.0     4.0
# 178285   2017     Lebanon                      Unknown    1.0     0.0
# 180321   2017     Lebanon            Bombing/Explosion    0.0     0.0
# 180350   2017     Lebanon  Hostage Taking (Kidnapping)    0.0     0.0
# 181557   2017     Lebanon                Assassination    0.0     0.0
#
#                                                     gname  \
# 158     Popular Front for the Liberation of Palestine ...
# 1005                                              Unknown
# 1448                                              Unknown
# 1606                                              Unknown
# 1669    Popular Front for the Liberation of Palestine ...
# ...                                                   ...
# 178169        Islamic State of Iraq and the Levant (ISIL)
# 178285        Islamic State of Iraq and the Levant (ISIL)
# 180321        Islamic State of Iraq and the Levant (ISIL)
# 180350                                          Hezbollah
# 181557                                            Unknown
#
#                       targtype1_txt weaptype1_txt  casualties
# 158         Government (Diplomatic)    Explosives         0.0
# 1005            Airports & Aircraft       Unknown         0.0
# 1448            Airports & Aircraft       Unknown         0.0
# 1606            Airports & Aircraft       Unknown         0.0
# 1669        Government (Diplomatic)    Explosives         0.0
# ...                             ...           ...         ...
# 178169                      Unknown    Explosives         5.0
# 178285                     Military       Unknown         1.0
# 180321                     Military    Explosives         0.0
# 180350  Private Citizens & Property       Unknown         0.0
# 181557         Government (General)    Explosives         0.0
#
# [2478 rows x 9 columns]

# %%
df[df["gname"] == "Hezbollah"]
# Out:
#         iyear country_txt              attacktype1_txt  nkill  nwound  \
# 18198    1983     Lebanon                Armed Assault    0.0     7.0
# 18293    1983     Lebanon            Bombing/Explosion    0.0     9.0
# 18307    1983     Lebanon            Bombing/Explosion    0.0     5.0
# 18572    1983     Lebanon            Bombing/Explosion   63.0   120.0
# 20075    1983     Lebanon            Bombing/Explosion  241.0    75.0
# ...       ...         ...                          ...    ...     ...
# 157320   2016      Israel            Bombing/Explosion    0.0     0.0
# 163587   2016     Lebanon            Bombing/Explosion    0.0     2.0
# 170354   2016       Syria  Hostage Taking (Kidnapping)    4.0     0.0
# 177376   2017     Lebanon            Bombing/Explosion    3.0     0.0
# 180350   2017     Lebanon  Hostage Taking (Kidnapping)    0.0     0.0
#
#             gname                targtype1_txt weaptype1_txt  casualties
# 18198   Hezbollah                     Military      Firearms         7.0
# 18293   Hezbollah                       Police    Explosives         9.0
# 18307   Hezbollah                     Military    Explosives         5.0
# 18572   Hezbollah      Government (Diplomatic)    Explosives       183.0
# 20075   Hezbollah                     Military    Explosives       316.0
# ...           ...                          ...           ...         ...
# 157320  Hezbollah                     Military    Explosives         0.0
# 163587  Hezbollah                     Business    Explosives         2.0
# 170354  Hezbollah               Transportation      Firearms         4.0
# 177376  Hezbollah  Private Citizens & Property    Explosives         3.0
# 180350  Hezbollah  Private Citizens & Property       Unknown         0.0
#
# [406 rows x 9 columns]
